# %% [markdown]
# <a href="https://colab.research.google.com/github/FavorTour2-coder/Machine-learning-with-Python-Boot-Camp/blob/main/Tour.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
A=2
B=3
C=2+3
print(C)
# Out:
# 5

# %% [markdown]
# Example of String

# %%
Greetings= "Advice na, pror"
print (Greetings)
# Out:
# Advice na, pror
