# %% [markdown]
# <a href="https://colab.research.google.com/github/FavorTour2-coder/Machine-learning-with-Python-Boot-Camp/blob/main/Python_refresher.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Variables

# %%
# Create a labeled storage basket and put a number inside
Tomato_price = 150
Pepper_price = 80

# Pull the value out of the baskets
print(Tomato_price)
print(Pepper_price)
# Out:
# 150
# 80

# %% [markdown]
# Variables (ML Anchor)

# %%
# --- THE CLUES (Features grouped as X) ---
rainfall_mm = 45.2  #Clue 1
bags_available = 100  #Clue 2

# ---- THE GOAL (Target labeled as y) ---
predicted_price = 3200 # What our AI calculates

print("Input (x):", rainfall_mm, "mm rain,", bags_available, "bags.")
print("output (y):",predicted_price,"LRD.")
# Out:
# Input (x): 45.2 mm rain, 100 bags.
# output (y): 3200 LRD.

# %% [markdown]
# Understanding Print Statement

# %%
Liberia = 1847
print (Liberia)
print ("liberia")
# Out:
# 1847
# liberia

# %% [markdown]
# understanding Variable

# %%
plum= 50
print("Plum previous price was :",plum)
plum =80
print("plum new price is:",plum)
# Out:
# Plum previous price was : 50
# plum new price is: 80

# %% [markdown]
# Data type

# %%
quantity = 50
price = 150.0
item_name = "tomatoes"
stall_is_open = True

print(type(quantity)) #
print(type(price)) #
print(type(item_name)) #
print(type(stall_is_open)) #
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>
